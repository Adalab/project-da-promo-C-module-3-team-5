# %%
# Lectura de datos
# ------------------------------------------------------------------------------
import pickle

# Tratamiento de datos
# ------------------------------------------------------------------------------
import numpy as np
import pandas as pd

# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Modelado y evaluación
# ------------------------------------------------------------------------------
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.model_selection import GridSearchCV

# Barra de progreso de un proceso
# ------------------------------------------------------------------------------
from tqdm import tqdm

# Configuración warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('once')

# %%
# Para ejecutar en google colab
#from google.colab import drive
#drive.mount('/content/drive/')

# %%
# Para conectar con Drive
#%cd /content/drive/My Drive/Colab Notebooks/

# %%
#import os

# %%
# Lectura del fichero
df = pd.read_pickle("datos/5.cnt_encoding_estandarizacion.pkl")
#df = pd.read_csv("project-da-promo-C-module-3-team-5/datos/4.reg_encoding_oh_final.csv", index_col=0)
df.head()
# Out:
#        dteday yr mnth dia_anual holiday_num weekday_num workingday_num  \
# 0  2018-01-01  0    1         1           1           0              0
# 1  2018-01-02  0    1         2           0           1              1
# 2  2018-01-03  0    1         3           0           2              1
# 3  2018-01-04  0    1         4           0           3              1
# 4  2018-01-05  0    1         5           0           4              1
#
#   weathersit   cnt seasons_autumn seasons_spring seasons_summer  \
# 0          2   985            0.0            0.0            0.0
# 1          2   801            0.0            0.0            0.0
# 2          1  1349            0.0            0.0            0.0
# 3          1  1562            0.0            0.0            0.0
# 4          1  1600            0.0            0.0            0.0
#
#   seasons_winter      temp     atemp       hum  windspeed    casual  \
# 0            1.0 -0.486274 -0.456399  0.863588  -0.216120 -0.494713
# 1            1.0 -0.425690 -0.492863  0.335222   0.711284 -0.751041
# 2            1.0 -0.949970 -1.098990 -0.910822   0.708863 -0.765139
# 3            1.0 -0.938563 -1.015201 -0.173433  -0.217699 -0.780519
# 4            1.0 -0.853992 -0.951952 -0.912344   0.062376 -0.813842
#
#    registered
# 0   -1.319816
# 1   -1.312801
# 2   -1.067733
# 3   -0.969093
# 4   -0.941035

# %%
# RandomForest
# X = Variables Predictoras
# y = Variable Respuesta
X = df[['holiday_num', 'weekday_num', 'workingday_num', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
       'seasons_autumn', 'seasons_spring', 'seasons_summer', 'seasons_winter']]
y = df['cnt']

# %%
# Generamos los conjuntos de train y test
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 43)

# %%
# Definimos un diccionario con los hiperparámetros que deberemos ocupar en el random forest
param = {"max_depth": [4,6,8],
        "max_features": [4,5,6,7],
        "min_samples_split": [5, 20, 75], 
        "min_samples_leaf": [5,20,75]}

# %%
# Aplicamos el GridSearch con estimador de RandomForestRegressor
gs_rf = GridSearchCV(
            estimator=RandomForestRegressor(), # tipo de modelo que queremos hacer
            param_grid= param, # que hiperparámetros queremos que testee
            cv=10, # crossvalidation que aprendimos en la lección de regresión lineal intro. 
            verbose=-1) # para que no nos printee ningún mensaje en pantalla

# %%
# Entrenamos el modelo con .fit()
gs_rf.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [4, 6, 8], 'max_features': [4, 5, 6, 7],
#                          'min_samples_leaf': [5, 20, 75],
#                          'min_samples_split': [5, 20, 75]},
#              verbose=-1)

# %%
with open("datos/7.cnt_encoding_estandar_oh_final_gs_rf.pkl", "wb") as f:
    pickle.dump(gs_rf, f)

# %%
# método para que elija el mejor estimador o combinación de valores
bosque = gs_rf.best_estimator_
bosque
# Out:
# RandomForestRegressor(max_depth=8, max_features=6, min_samples_leaf=5,
#                       min_samples_split=5)

# %%
# Aplicamos el método .predict() para calcular las métricas del mejor modelo.
y_pred_test_rf = bosque.predict(x_test)
y_pred_train_rf = bosque.predict(x_train)

# %%
# Plotear un árbol del RandomForest
plt.figure(figsize=(20,10))
tree.plot_tree(bosque.estimators_[50],feature_names=x_train.columns,filled=True)
plt.show()

# %%
# Medimos las métricas del random forest
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):    
    resultados = {'MAE': [mean_absolute_error(y_test, y_test_pred), mean_absolute_error(y_train, y_train_pred)],
                'MSE': [mean_squared_error(y_test, y_test_pred), mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(mean_squared_error(y_test, y_test_pred)), np.sqrt(mean_squared_error(y_train, y_train_pred))],
                'R2':  [r2_score(y_test, y_test_pred), r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
# sacamos las métricas para ver si hay overfitting o unerfitting, para modificar la profundidad en función de estos resultados
rf_results = metricas(y_test, y_train, y_pred_test_rf, y_pred_train_rf, "CNT Cod-Est Random Forest")
rf_results
# Out:
#            MAE           MSE         RMSE        R2    set  \
# 0  1041.760204  1.505422e+06  1226.956317  0.567971   test
# 1   796.584581  8.809101e+05   938.568135  0.768637  train
#
#                       modelo
# 0  CNT Cod-Est Random Forest
# 1  CNT Cod-Est Random Forest

# %%
# Cargamos el archivo con las mejores métricas del Decision Tree
df_DT_results = pd.read_csv("datos/7.cnt_resultados_cod_rf_mas_dt.csv", index_col = 0)
df_DT_results
# Out:
#            MAE           MSE         RMSE        R2    set  \
# 2  1156.178519  1.970333e+06  1403.685382  0.424358   test
# 3   898.989340  1.207631e+06  1098.922588  0.683509  train
# 6  1178.026531  2.010211e+06  1417.818924  0.412707   test
# 7   933.555724  1.257530e+06  1121.396274  0.670432  train
# 0  1025.763941  1.493976e+06  1222.283271  0.571256   test
# 1   840.475265  9.855776e+05   992.762603  0.741147  train
#
#                               modelo
# 2  CNT_est_ Decision tree II Est-Cod
# 3  CNT_est_ Decision tree II Est-Cod
# 6           CNT_Cod_Decision tree II
# 7           CNT_Cod_Decision tree II
# 0              CNT Cod Random Forest
# 1              CNT Cod Random Forest

# %%
#Unimos los resultados del Random Forest y el Decision Tree:
df_RF_DT_results = pd.concat([df_DT_results, rf_results], axis=0)
df_RF_DT_results
# Out:
#            MAE           MSE         RMSE        R2    set  \
# 2  1156.178519  1.970333e+06  1403.685382  0.424358   test
# 3   898.989340  1.207631e+06  1098.922588  0.683509  train
# 6  1178.026531  2.010211e+06  1417.818924  0.412707   test
# 7   933.555724  1.257530e+06  1121.396274  0.670432  train
# 0  1025.763941  1.493976e+06  1222.283271  0.571256   test
# 1   840.475265  9.855776e+05   992.762603  0.741147  train
# 0  1041.760204  1.505422e+06  1226.956317  0.567971   test
# 1   796.584581  8.809101e+05   938.568135  0.768637  train
#
#                               modelo
# 2  CNT_est_ Decision tree II Est-Cod
# 3  CNT_est_ Decision tree II Est-Cod
# 6           CNT_Cod_Decision tree II
# 7           CNT_Cod_Decision tree II
# 0              CNT Cod Random Forest
# 1              CNT Cod Random Forest
# 0          CNT Cod-Est Random Forest
# 1          CNT Cod-Est Random Forest

# %%
# vamos a crearnos un dataframe 
importancia_predictores = pd.DataFrame({'predictor': x_train.columns,
    'importancia': bosque.feature_importances_})

# ordenamos de mayor a menor los resultados
importancia_predictores.sort_values(by=["importancia"], ascending=False, inplace = True)
importancia_predictores
# Out:
#          predictor  importancia
# 5            atemp     0.358698
# 4             temp     0.264848
# 6              hum     0.127203
# 11  seasons_winter     0.075484
# 7        windspeed     0.064460
# 8   seasons_autumn     0.040206
# 3       weathersit     0.024239
# 1      weekday_num     0.021132
# 10  seasons_summer     0.011086
# 9   seasons_spring     0.008025
# 2   workingday_num     0.003116
# 0      holiday_num     0.001503

# %%
df_RF_DT_results.to_csv("datos/7.cnt_resultados_cod_est_rf_dt.csv")
